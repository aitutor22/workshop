# %%
# Following code is for illustration only
# coding style is optimised for easy understanding and does not follow python best practises

# we import external libraries (note: you would need to install these libraries using pip, etc)
import pandas

# https://forex-python.readthedocs.io/en/latest/usage.html
from forex_python.converter import CurrencyRates

# user created library
# power of functions, we don't need to write all the stuff ourselves
# stand on the shoulders of giants (or an outsourced technical team)
import currency

# %%
df = pandas.read_csv('https://bit.ly/2VzG6O7')

# %%
df
# Out:
#    Customer Id    Country                               Product  \
# 0            8  Hong Kong                       iPad Air (pink)
# 1         1011      Japan                  Asus 200 motherboard
# 2          103  Hong Kong                          Samsung S10e
# 3            1  Hong Kong  Acer Swift 5 SF514-52T-815E Notebook
# 4            1  Hong Kong                             iPhone XS
# 5          301  Singapore                  Asus Chromebook C202
# 6            2  Hong Kong                         laptop (Asus)
#
#    Revenue Local Currency
# 0           3999      HKD
# 1           8548      JPY
# 2           5258      HKD
# 3           8298      HKD
# 4           8599      HKD
# 5            392      SGD
# 6           9998      HKD

# %%
def get_brand(val):
    # converts to lowercase and strip away white space     
    val = val.lower().strip()
    
    if 'ipad' in val:
        return 'apple'
    elif 'iphone' in val:
        return 'apple'
    elif 'acer' in val:
        return 'acer'
    elif 'asus' in val:
        return 'asus'
    elif 'samsung' in val:
        return 'samsung'

# %%
# creates a new column brand, formed by applying the get_brand function
# on every cell of the Product column
df['Brand'] = df['Product'].apply(get_brand)
df
# Out:
#    Customer Id    Country                               Product  \
# 0            8  Hong Kong                       iPad Air (pink)
# 1         1011      Japan                  Asus 200 motherboard
# 2          103  Hong Kong                          Samsung S10e
# 3            1  Hong Kong  Acer Swift 5 SF514-52T-815E Notebook
# 4            1  Hong Kong                             iPhone XS
# 5          301  Singapore                  Asus Chromebook C202
# 6            2  Hong Kong                         laptop (Asus)
#
#    Revenue Local Currency    Brand
# 0           3999      HKD    apple
# 1           8548      JPY     asus
# 2           5258      HKD  samsung
# 3           8298      HKD     acer
# 4           8599      HKD    apple
# 5            392      SGD     asus
# 6           9998      HKD     asus

# %%
# let's say we wanted to convert local currency to SGD (or USD)
c = CurrencyRates()
df['Exchange Rate'] = df['Currency'].apply(c.get_rate, args=('SGD',))

# %%
df
# Out:
#    Customer Id    Country                               Product  \
# 0            8  Hong Kong                       iPad Air (pink)
# 1         1011      Japan                  Asus 200 motherboard
# 2          103  Hong Kong                          Samsung S10e
# 3            1  Hong Kong  Acer Swift 5 SF514-52T-815E Notebook
# 4            1  Hong Kong                             iPhone XS
# 5          301  Singapore                  Asus Chromebook C202
# 6            2  Hong Kong                         laptop (Asus)
#
#    Revenue Local Currency    Brand  Exchange Rate
# 0           3999      HKD    apple       0.172592
# 1           8548      JPY     asus       0.012169
# 2           5258      HKD  samsung       0.172592
# 3           8298      HKD     acer       0.172592
# 4           8599      HKD    apple       0.172592
# 5            392      SGD     asus       1.000000
# 6           9998      HKD     asus       0.172592

# %%
# creates a new column "Revenue SGD"
df['Revenue SGD'] = df['Revenue Local'] * df['Exchange Rate']
df
# Out:
#    Customer Id    Country                               Product  \
# 0            8  Hong Kong                       iPad Air (pink)
# 1         1011      Japan                  Asus 200 motherboard
# 2          103  Hong Kong                          Samsung S10e
# 3            1  Hong Kong  Acer Swift 5 SF514-52T-815E Notebook
# 4            1  Hong Kong                             iPhone XS
# 5          301  Singapore                  Asus Chromebook C202
# 6            2  Hong Kong                         laptop (Asus)
#
#    Revenue Local Currency    Brand  Exchange Rate  Revenue SGD
# 0           3999      HKD    apple       0.172592   690.195600
# 1           8548      JPY     asus       0.012169   104.024074
# 2           5258      HKD  samsung       0.172592   907.488988
# 3           8298      HKD     acer       0.172592  1432.168814
# 4           8599      HKD    apple       0.172592  1484.119021
# 5            392      SGD     asus       1.000000   392.000000
# 6           9998      HKD     asus       0.172592  1725.575296

# %%
# exports to a new csv file, which can be then modified in excel
df.to_csv('edited_data.csv')
